# %%
from math import exp
from random import random
import numpy as np
import math

def actF(x):
    act = math.tanh(x)
    return [act,1-act*act]

def softmax_norm(output_vec):
    l = [exp(x) for x in output_vec]
    npl = np.array(l)
    mysum = npl.sum()
    Dr = np.array([mysum for i in range(0,len(output_vec))])
    return (npl/Dr)

def loss_(ftype,softmax_output_vec,target_vec):
    if ftype == "cross_entropy":
        return (softmax_output_vec - target_vec)


def init_NN(inputNeurons, hiddenNeurons, outputNeurons ):
    net = []
    hidden_layer = []
    output_layer = []
    weights = []
    temp = []
    for i in range(inputNeurons + 1):
        for i in range(hiddenNeurons):
            weights.append(random())
        
    weights = np.array(weights)
    weights = weights.reshape(hiddenNeurons,inputNeurons+1);
    hidden_layer = {'weights': weights}
    net.append(hidden_layer)
    
    weights = []
    for i in range(hiddenNeurons):
        for i in range(outputNeurons+1):
            weights.append(random())
        
    weights = np.array(weights).reshape(hiddenNeurons,outputNeurons+1)
    output_layer = {'weights' : weights}
    net.append(output_layer)
    return net
    

        

NN = init_NN(2,4,2)
dataset = open('dataset.txt','r')

dataset = [line.split() for line in dataset]
temp1 = []

for i in dataset:
    temp = []
    for j in i:
         temp.append(float(j))
    temp1.append(temp)

dataset = np.array(temp1)

trainset = [[i[0],i[1]] for i in dataset]


for row in trainset :
    row.append(1)
    row = np.array(row)
    row = row.reshape(1,3)
    weights = net[0]['weights']
    weights = np.transpose(np.array(weights))
#     print(row)
#     print(weights)
#     output = actF(row*weights)

def forward_prop(NN, input_vector):
    for layer in NN:
        new_inputs = []
        for neuron in layer:
            new_inputs.append(NN[layer]['weights'])
            
            
layer = 0
input_vector = trainset[0]

print(NN[layer]['weights'])
print(input_vector)
new_inputs = []
activation = [actF(i[0]+i[1]) + i[2] for i in NN[layer]['weights']*input_vector]
new_inputs.append([i[0] for i in activation])
# derivatives = {'derivatives' : activation[1]}

# print(NN[layer])

print(activation)
print("")
print(new_inputs)
print("")
print(NN[1])
# print(derivatives)


    
# print(temp1)

# input = nd.arra
# output = actF()
# Out:
# [[0.54917786 0.42001615 0.57457156]
#  [0.50326338 0.64067505 0.86133715]
#  [0.95078326 0.75525684 0.40983225]
#  [0.47772011 0.17303111 0.21656305]]
# [-0.31445, 0.662022, 1]
# [array([0.67955426, 1.5635502 ]), array([1.12113331, 1.7938431 ]), array([0.60819037, 1.37048631]), array([0.18090948, 1.21529187])]
#
# [[0.6795542599940656, 1.1211333145806321, 0.6081903745773362, 0.18090948382687372]]
#
# {'weights': array([[0.88634189, 0.7514867 , 0.63511918],
#        [0.35234662, 0.88842276, 0.59691648],
#        [0.00732727, 0.38531802, 0.76817873],
#        [0.90457776, 0.9238795 , 0.26671054]])}

# %%
import numpy as np
from scipy.optimize import fmin
import math

def f(x):
    return(1.5*(x[0]**2) + x[1]**2 - 2*x[0]*x[1] + 0.5*(x[0]**4))

fmin(f,np.array([1,-3]))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 89
# array([ 3.57508783e-06, -2.30531209e-05])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np

def f(x1,x2):
    return(1.5*(x1**2) + x2**2 - 2*x1*x2 + 2*x1**3 + 0.5*(x1**4))

fig = plt.figure()
ax = fig.gca(projection='3d')

x1 = np.arange(-10,10,0.5)
x2 = np.arange(-10,10,0.5)
x = np.array([x1,x2])

x1,x2 = np.meshgrid(x1,x2)
z = f(x1,x2)

surf = ax.plot_surface(x1, x2, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

plt.show()


print(x1)
# Out:
# [[-10.   -9.5  -9.  ...   8.5   9.    9.5]
#  [-10.   -9.5  -9.  ...   8.5   9.    9.5]
#  [-10.   -9.5  -9.  ...   8.5   9.    9.5]
#  ...
#  [-10.   -9.5  -9.  ...   8.5   9.    9.5]
#  [-10.   -9.5  -9.  ...   8.5   9.    9.5]
#  [-10.   -9.5  -9.  ...   8.5   9.    9.5]]
